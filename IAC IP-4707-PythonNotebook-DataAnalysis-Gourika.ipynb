# %% [markdown]
# **INTRODUCTION**
# In today’s competitive job market, a resume plays a critical role in landing an internship or job. With recruiters spending only a few minutes reviewing each resume, over 70% are rejected in the initial screening.
#
# This project aims to analyze the connection between students' academic performance, event participation, career goals, and their chances of success. By studying a dataset of student interns, we hope to gain useful insights into what helps students stand out and improve their chances of securing opportunities.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Load the Excel file into a pandas DataFrame for data analysis
df = pd.read_excel('/content/Data analyst Data (1).xlsx')

# %%
# Display the first few rows of the dataframe to check if the data loaded correctly
print(df.head())
# Out:
#   First Name           Email ID  Quantity                  Events  \
# 0     ANIKET     aniket@xyz.com         1  Art of Resume Building
# 1  Dhanshree  dhanshree@xyz.com         1  Art of Resume Building
# 2     Dhiraj     dhiraj@xyz.com         1  Art of Resume Building
# 3      Pooja      pooja@xyz.com         1  Art of Resume Building
# 4     Aayush     aayush@xyz.com         1  Art of Resume Building
#
#   Attendee Status                                       College Name  \
# 0       Attending  D Y PATIL INSTITUTE OF MCA AND MANAGEMENT AKUR...
# 1       Attending                   AP SHAH INSTITUTE OF TECHNOLOGY
# 2       Attending       Don Bosco College of Engineering Fatorda Goa
# 3       Attending           Pillai College of Engineering New Panvel
# 4       Attending                               St Xavier's College
#
#         How did you come to know about this event?  \
# 0                                            Email
# ...

# %%
# Convert the dictionary into a DataFrame
df = pd.DataFrame(df)

# %%
df.head()
# Out:
#   First Name           Email ID  Quantity                  Events  \
# 0     ANIKET     aniket@xyz.com         1  Art of Resume Building
# 1  Dhanshree  dhanshree@xyz.com         1  Art of Resume Building
# 2     Dhiraj     dhiraj@xyz.com         1  Art of Resume Building
# 3      Pooja      pooja@xyz.com         1  Art of Resume Building
# 4     Aayush     aayush@xyz.com         1  Art of Resume Building
#
#   Attendee Status                                       College Name  \
# 0       Attending  D Y PATIL INSTITUTE OF MCA AND MANAGEMENT AKUR...
# 1       Attending                   AP SHAH INSTITUTE OF TECHNOLOGY
# 2       Attending       Don Bosco College of Engineering Fatorda Goa
# 3       Attending           Pillai College of Engineering New Panvel
# 4       Attending                               St Xavier's College
#
#         How did you come to know about this event?  \
# 0                                            Email
# ...

# %% [markdown]
# First Name: Identifies the student by their first name.
#
# Email ID: Contains the student's email address.
#
# Quantity: Indicates the number of courses the student has completed.
#
# Events: Lists the event in which the student participated.
#
# Attendee Status: Shows whether the student is attending the event.
#
# College Name: Specifies the college from which the student graduates.
#
# Year of Graduation: Denotes the year the student completed or will complete their graduation.
#
# City: Captures the student's city of residence or hometown.
#
# CGPA: Represents the student's academic performance as a Grade Point Average.
#
# Experience with Python (Months): Indicates how many months of experience the student has with Python programming.
#
# Family Income: Denotes the income level of the student's family.
#
# Expected Salary (Lac): Indicates the salary the student expects after graduation.
#
# Leadership Skills: Indicates whether the student possesses leadership skills.

# %%
# Summary statistics for numerical columns
df.describe()
# Out:
#        Quantity  Year of Graduation         CGPA  \
# count    4894.0         4894.000000  4894.000000
# mean        1.0         2024.176951     8.038476
# std         0.0            1.000180     1.005184
# min         1.0         2023.000000     6.200000
# 25%         1.0         2023.000000     7.200000
# 50%         1.0         2024.000000     7.900000
# 75%         1.0         2025.000000     8.900000
# max         1.0         2026.000000     9.900000
#
#        Experience with python (Months)  Expected salary (Lac)
# count                      4894.000000            4894.000000
# mean                          5.395586              13.935635
# std                           1.705364               6.451959
# min                           3.000000               5.000000
# 25%                           4.000000               8.000000
# 50%                           5.000000              13.000000
# 75%                           7.000000              19.000000
# ...

# %%
# Check the data types of the dataframe
def check_data_types(dataframe):
    """
    This function prints the data type of each column in the provided DataFrame.

    Parameters:
    dataframe (pd.DataFrame): The DataFrame to check the data types of its columns.

    Returns:
    None
    """
    data_types = dataframe.dtypes
    print(data_types)

# Call the function to check the data types in the DataFrame 'df'
check_data_types(df)
# Out:
# First Name                                                          object
# Email ID                                                            object
# Quantity                                                             int64
# Events                                                              object
# Attendee Status                                                     object
# College Name                                                        object
# How did you come to know about this event?                          object
# Specify in "Others" (how did you come to know about this event)     object
# Designation                                                         object
# Year of Graduation                                                   int64
# City                                                                object
# CGPA                                                               float64
# ...

# %%
df.head()
# Out:
#   First Name           Email ID  Quantity                  Events  \
# 0     ANIKET     aniket@xyz.com         1  Art of Resume Building
# 1  Dhanshree  dhanshree@xyz.com         1  Art of Resume Building
# 2     Dhiraj     dhiraj@xyz.com         1  Art of Resume Building
# 3      Pooja      pooja@xyz.com         1  Art of Resume Building
# 4     Aayush     aayush@xyz.com         1  Art of Resume Building
#
#   Attendee Status                                       College Name  \
# 0       Attending  D Y PATIL INSTITUTE OF MCA AND MANAGEMENT AKUR...
# 1       Attending                   AP SHAH INSTITUTE OF TECHNOLOGY
# 2       Attending       Don Bosco College of Engineering Fatorda Goa
# 3       Attending           Pillai College of Engineering New Panvel
# 4       Attending                               St Xavier's College
#
#         How did you come to know about this event?  \
# 0                                            Email
# ...

# %%
#Change the datatype and numerical value of Family Income
import re

def convert_lakh_to_numeric(lakh_str):
    """
    Convert a 'Lakh' value string to its numeric equivalent.

    Parameters:
    lakh_str (str): The string containing the Lakh value.

    Returns:
    float: The numeric equivalent of the Lakh value.
    """
    # Check if the value is a range (e.g., "5-7 Lakh")
    if '-' in lakh_str:
        # Extract the two numbers
        start, end = map(int, re.findall(r'\d+', lakh_str))
        # Convert to numeric and take the average
        return (start * 100000 + end * 100000) / 2
    elif 'Lakh+' in lakh_str:
        # Handle case like "7 Lakh+"
        number = int(re.search(r'\d+', lakh_str).group())
        return number * 100000
    elif 'Lakh' in lakh_str:
        # Handle cases like "5 Lakh"
        number = int(re.search(r'\d+', lakh_str).group())
        return number * 100000
    else:
        # If the format is unexpected, return NaN or handle as needed
        return None

# Apply the function to the 'Family Income' column and update it in place
df['Family Income'] = df['Family Income'].apply(convert_lakh_to_numeric)

# Display the updated DataFrame
print(df[['Family Income']])
# Out:
#       Family Income
# 0          700000.0
# 1          100000.0
# 2          600000.0
# 3          350000.0
# 4          100000.0
# ...             ...
# 4889       100000.0
# 4890       100000.0
# 4891       100000.0
# 4892       100000.0
# 4893       100000.0
#
# [4894 rows x 1 columns]

# %%
df
# Out:
#         First Name              Email ID  Quantity  \
# 0           ANIKET        aniket@xyz.com         1
# 1        Dhanshree     dhanshree@xyz.com         1
# 2           Dhiraj        dhiraj@xyz.com         1
# 3            Pooja         pooja@xyz.com         1
# 4           Aayush        aayush@xyz.com         1
# ...            ...                   ...       ...
# 4889   Patel Niraj    patelniraj@xyz.com         1
# 4890         VIDIT         vidit@xyz.com         1
# 4891  Suryaprakash  suryaprakash@xyz.com         1
# 4892      Saif ali       saifali@xyz.com         1
# 4893       Lankesh       lankesh@xyz.com         1
#
#                                  Events Attendee Status  \
# 0                Art of Resume Building       Attending
# 1                Art of Resume Building       Attending
# 2                Art of Resume Building       Attending
# 3                Art of Resume Building       Attending
# 4                Art of Resume Building       Attending
# ...

# %%
# Change the numerical value of expected salary
def convert_salary_to_numeric(salary_str):
    """
    Convert an 'Expected salary (Lac)' value string to its numeric equivalent in full value.

    Parameters:
    salary_str (str): The string containing the salary value in Lac.

    Returns:
    float: The numeric equivalent of the salary value in full value.
    """
    try:
        # Check if the salary string is already numeric
        if isinstance(salary_str, (int, float)):
            return float(salary_str) * 100000

        # Extract the numeric part from the string and convert to full numeric value
        number = float(salary_str)
        return number * 100000
    except ValueError:
        # Handle cases where conversion fails
        return None

# Apply the function to the 'Expected salary (Lac)' column and update it in place
df['Expected salary (Lac)'] = df['Expected salary (Lac)'].apply(convert_salary_to_numeric)

# Display the updated DataFrame to confirm the conversion
print(df[['Expected salary (Lac)']])
# Out:
#       Expected salary (Lac)
# 0                  600000.0
# 1                  700000.0
# 2                  700000.0
# 3                  800000.0
# 4                 1000000.0
# ...                     ...
# 4889              1500000.0
# 4890               800000.0
# 4891               700000.0
# 4892              2300000.0
# 4893               900000.0
#
# [4894 rows x 1 columns]

# %%
df
# Out:
#         First Name              Email ID  Quantity  \
# 0           ANIKET        aniket@xyz.com         1
# 1        Dhanshree     dhanshree@xyz.com         1
# 2           Dhiraj        dhiraj@xyz.com         1
# 3            Pooja         pooja@xyz.com         1
# 4           Aayush        aayush@xyz.com         1
# ...            ...                   ...       ...
# 4889   Patel Niraj    patelniraj@xyz.com         1
# 4890         VIDIT         vidit@xyz.com         1
# 4891  Suryaprakash  suryaprakash@xyz.com         1
# 4892      Saif ali       saifali@xyz.com         1
# 4893       Lankesh       lankesh@xyz.com         1
#
#                                  Events Attendee Status  \
# 0                Art of Resume Building       Attending
# 1                Art of Resume Building       Attending
# 2                Art of Resume Building       Attending
# 3                Art of Resume Building       Attending
# 4                Art of Resume Building       Attending
# ...

# %%
def plot_data_distribution(dataframe, bins=20):
    """
    Plot histograms for the numeric columns in the provided DataFrame to check data distribution.

    Parameters:
    dataframe (pd.DataFrame): The DataFrame containing the data to analyze.
    bins (int): The number of bins for the histograms (default is 20).

    Returns:
    None
    """
    # Select numeric columns
    numeric_columns = dataframe.select_dtypes(include=['int64', 'float64']).columns

    if not numeric_columns.any():
        print("No numeric columns found in the DataFrame.")
        return

    # Create histograms for each numeric column
    for column in numeric_columns:
        plt.figure(figsize=(10, 6))
        sns.histplot(dataframe[column].dropna(), bins=bins, kde=False)
        plt.title(f'Distribution of {column}')
        plt.xlabel(column)
        plt.ylabel('Frequency')
        plt.grid(True)
        plt.show()

# Example usage:
plot_data_distribution(df)

# %%
# Check for missing values in the DataFrame
missing_values = df.isnull().sum()

# Display the missing values for each column
print(missing_values)
# Out:
# First Name                                                            0
# Email ID                                                              0
# Quantity                                                              0
# Events                                                                0
# Attendee Status                                                       0
# College Name                                                         15
# How did you come to know about this event?                         2216
# Specify in "Others" (how did you come to know about this event)    4805
# Designation                                                           0
# Year of Graduation                                                    0
# City                                                                  0
# CGPA                                                                  0
# Experience with python (Months)                                       0
# ...

# %%
df.shape894
#we have 4 rows and 16 columns if you have 10 rows and 6 of them have missing values so you cannot drop those rows.
#for eg if you have 2 missing values then you can drop those values
# Out:
# (4894, 16)

# %%
import pandas as pd

def replace_nan_with_others(dataframe):
    # Replace NaN values in the specified column with 'Others'
    dataframe['Specify in "Others" (how did you come to know about this event)'] = \
        dataframe['Specify in "Others" (how did you come to know about this event)'].fillna('Others')

    return dataframe

# Example usage:
df = replace_nan_with_others(df)

# Display the updated DataFrame to confirm changes
print(df[['Specify in "Others" (how did you come to know about this event)']])
# Out:
#      Specify in "Others" (how did you come to know about this event)
# 0                                                Others
# 1                                               College
# 2                                                Others
# 3                                                Others
# 4                                                Others
# ...                                                 ...
# 4889                                             Others
# 4890                                             Others
# 4891                                             Others
# 4892                                             Others
# 4893                                             Others
#
# [4894 rows x 1 columns]

# %%
df
# Out:
#         First Name              Email ID  Quantity  \
# 0           ANIKET        aniket@xyz.com         1
# 1        Dhanshree     dhanshree@xyz.com         1
# 2           Dhiraj        dhiraj@xyz.com         1
# 3            Pooja         pooja@xyz.com         1
# 4           Aayush        aayush@xyz.com         1
# ...            ...                   ...       ...
# 4889   Patel Niraj    patelniraj@xyz.com         1
# 4890         VIDIT         vidit@xyz.com         1
# 4891  Suryaprakash  suryaprakash@xyz.com         1
# 4892      Saif ali       saifali@xyz.com         1
# 4893       Lankesh       lankesh@xyz.com         1
#
#                                  Events Attendee Status  \
# 0                Art of Resume Building       Attending
# 1                Art of Resume Building       Attending
# 2                Art of Resume Building       Attending
# 3                Art of Resume Building       Attending
# 4                Art of Resume Building       Attending
# ...

# %%
# Apply function with condition to handle NaN or missing values
df['How did you come to know about this event?'] = df['How did you come to know about this event?'].apply(
    lambda x: x.split(' | ')[0] if isinstance(x, str) else x
)

# %%
df.head()
# Out:
#   First Name           Email ID  Quantity                  Events  \
# 0     ANIKET     aniket@xyz.com         1  Art of Resume Building
# 1  Dhanshree  dhanshree@xyz.com         1  Art of Resume Building
# 2     Dhiraj     dhiraj@xyz.com         1  Art of Resume Building
# 3      Pooja      pooja@xyz.com         1  Art of Resume Building
# 4     Aayush     aayush@xyz.com         1  Art of Resume Building
#
#   Attendee Status                                       College Name  \
# 0       Attending  D Y PATIL INSTITUTE OF MCA AND MANAGEMENT AKUR...
# 1       Attending                   AP SHAH INSTITUTE OF TECHNOLOGY
# 2       Attending       Don Bosco College of Engineering Fatorda Goa
# 3       Attending           Pillai College of Engineering New Panvel
# 4       Attending                               St Xavier's College
#
#   How did you come to know about this event?  \
# 0                                      Email
# 1                                     Others
# ...

# %%
# Find the mode (most frequent value) of the column
mode_value = df['How did you come to know about this event?'].mode()[0]

# Fill the null values with the mode
df['How did you come to know about this event?'].fillna(mode_value, inplace=True)

df.head()
# Out:
# <ipython-input-20-f5759ee6d2bb>:5: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['How did you come to know about this event?'].fillna(mode_value, inplace=True)
#   First Name           Email ID  Quantity                  Events  \
# 0     ANIKET     aniket@xyz.com         1  Art of Resume Building
# 1  Dhanshree  dhanshree@xyz.com         1  Art of Resume Building
# 2     Dhiraj     dhiraj@xyz.com         1  Art of Resume Building
# 3      Pooja      pooja@xyz.com         1  Art of Resume Building
# ...

# %%
# Check for missing values in the DataFrame
missing_values = df.isnull().sum()

# Display the missing values for each column
print(missing_values)
# Out:
# First Name                                                          0
# Email ID                                                            0
# Quantity                                                            0
# Events                                                              0
# Attendee Status                                                     0
# College Name                                                       15
# How did you come to know about this event?                          0
# Specify in "Others" (how did you come to know about this event)     0
# Designation                                                         0
# Year of Graduation                                                  0
# City                                                                0
# CGPA                                                                0
# Experience with python (Months)                                     0
# ...

# %%
# Drop rows with NaN values in the 'College Name' column
df.dropna(subset=['College Name'], inplace=True)

# %%
df
# Out:
#         First Name              Email ID  Quantity  \
# 0           ANIKET        aniket@xyz.com         1
# 1        Dhanshree     dhanshree@xyz.com         1
# 2           Dhiraj        dhiraj@xyz.com         1
# 3            Pooja         pooja@xyz.com         1
# 4           Aayush        aayush@xyz.com         1
# ...            ...                   ...       ...
# 4889   Patel Niraj    patelniraj@xyz.com         1
# 4890         VIDIT         vidit@xyz.com         1
# 4891  Suryaprakash  suryaprakash@xyz.com         1
# 4892      Saif ali       saifali@xyz.com         1
# 4893       Lankesh       lankesh@xyz.com         1
#
#                                  Events Attendee Status  \
# 0                Art of Resume Building       Attending
# 1                Art of Resume Building       Attending
# 2                Art of Resume Building       Attending
# 3                Art of Resume Building       Attending
# 4                Art of Resume Building       Attending
# ...

# %%
# Loop through each column and find unique values
for column in df.columns:
    unique_values = df[column].unique()  # Get unique values for the column
    print(f"Unique values in '{column}' column: {unique_values}")
# Out:
# Unique values in 'First Name' column: ['ANIKET' 'Dhanshree' 'Dhiraj' ... 'Suryaprakash' 'Saif ali' 'Lankesh']
# Unique values in 'Email ID' column: ['aniket@xyz.com' 'dhanshree@xyz.com' 'dhiraj@xyz.com' ...
#  'suryaprakash@xyz.com' 'saifali@xyz.com' 'lankesh@xyz.com']
# Unique values in 'Quantity' column: [1]
# Unique values in 'Events' column: ['Art of Resume Building' 'Data Visualization using Power BI'
#  'Artificial Intelligence' 'Hello ML and DL' 'Product Marketing'
#  'IAC - Q&A' 'Internship Program(IP) Success Conclave'
#  'IS DATA SCIENCE FOR YOU?' 'KYC - Know Your CCPC'
#  'Product Design & Full Stack' 'RPA: A Boon or A Bane'
#  'Skill and Employability Enhancement'
#  'Talk on Skill and Employability Enhancement' 'The Agile Ways of Working'
#  'The SDLC & their transformations'
#  'Transformation with DevOps: The Easy Way']
# Unique values in 'Attendee Status' column: ['Attending' 'NAN']
# ...

# %%
# Replace NaN values with 'Absent' in the 'Attendee Status' column
df['Attendee Status'].fillna('Absent', inplace=True)
# Out:
# <ipython-input-25-7a006d4ce563>:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Attendee Status'].fillna('Absent', inplace=True)

# %%
# Check for missing values in the DataFrame
missing_values = df.isnull().sum()

# Display the missing values for each column
print(missing_values)
# Out:
# First Name                                                         0
# Email ID                                                           0
# Quantity                                                           0
# Events                                                             0
# Attendee Status                                                    0
# College Name                                                       0
# How did you come to know about this event?                         0
# Specify in "Others" (how did you come to know about this event)    0
# Designation                                                        0
# Year of Graduation                                                 0
# City                                                               0
# CGPA                                                               0
# Experience with python (Months)                                    0
# Family Income                                                      0
# ...

# %%
# Replace 'no ' with 'no' in the 'Leadership- skills' column
df['Leadership- skills'] = df['Leadership- skills'].replace('no ', 'no')

print(df['Leadership- skills'].unique())  # Verify the unique values after replacement
# Out:
# ['yes' 'no']

# %%
# Drop duplicate rows based on all columns and keep the first occurrence
df.drop_duplicates(inplace=True)

# Display the DataFrame after removing duplicates
df.head()
# Out:
#   First Name           Email ID  Quantity                  Events  \
# 0     ANIKET     aniket@xyz.com         1  Art of Resume Building
# 1  Dhanshree  dhanshree@xyz.com         1  Art of Resume Building
# 2     Dhiraj     dhiraj@xyz.com         1  Art of Resume Building
# 3      Pooja      pooja@xyz.com         1  Art of Resume Building
# 4     Aayush     aayush@xyz.com         1  Art of Resume Building
#
#   Attendee Status                                       College Name  \
# 0       Attending  D Y PATIL INSTITUTE OF MCA AND MANAGEMENT AKUR...
# 1       Attending                   AP SHAH INSTITUTE OF TECHNOLOGY
# 2       Attending       Don Bosco College of Engineering Fatorda Goa
# 3       Attending           Pillai College of Engineering New Panvel
# 4       Attending                               St Xavier's College
#
#   How did you come to know about this event?  \
# 0                                      Email
# 1                                     Others
# ...

# %% [markdown]
# # BASIC QUESTIONS:
#
# **Question 1**: How many unique students are included in the dataset?
#
# **Answer:** Number of unique students in the dataset: 2152

# %%
# Calculate the number of unique students based on the 'Email ID' column
unique_students_count = df['Email ID'].nunique()

print(f"Number of unique students in the dataset: {unique_students_count}")
# Out:
# Number of unique students in the dataset: 2152

# %% [markdown]
# **Question 2:** What is the average GPA of the students?
#
# **Answer:** Average GPA (CGPA) of the students: 8.038286534125847

# %%
# Calculate the average CGPA of the students
average_cgpa = df['CGPA'].mean()

print(f"Average GPA (CGPA) of the students: {average_cgpa}")
# Out:
# Average GPA (CGPA) of the students: 8.038286534125847

# %% [markdown]
# **Question 3:** What is the distribution of students across different graduation years?
#
# **Answer:** Distribution of students across different graduation years:
# Year of Graduation
#
# 2023  :  1530
#
# 2024  :  1506
#
# 2025  :  1289
#
# 2026  :  554

# %%
# Get the distribution of students across different graduation years
year_distribution = df['Year of Graduation'].value_counts()

print("Distribution of students across different graduation years:")
print(year_distribution)
# Out:
# Distribution of students across different graduation years:
# Year of Graduation
# 2023    1530
# 2024    1506
# 2025    1289
# 2026     554
# Name: count, dtype: int64

# %%
#Plot the distribution of students across graduation years
import matplotlib.pyplot as plt

# Get the distribution of students across different graduation years
year_distribution = df['Year of Graduation'].value_counts()

# Sort the distribution by year (optional, for better readability)
year_distribution = year_distribution.sort_index()

# Plotting
plt.figure(figsize=(10, 6))
year_distribution.plot(kind='bar', color='skyblue')
plt.title('Distribution of Students Across Different Graduation Years')
plt.xlabel('Year of Graduation')
plt.ylabel('Number of Students')
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()  # Adjust layout to fit labels
plt.show()

# %% [markdown]
# **Question 4:**  What is the distribution of student's experience with Python programming?
#
# **Answer:**
#
# MONTH  -    NO. OF STUDENTS
#
#   3   - 1006
#
#   4      -       463
#
#   5      -      1239
#
#   6       -      738
#
#   7      -       633
#
#   8       -      800

# %%
# Get the distribution of students' experience with Python programming
experience_distribution = df['Experience with python (Months)'].value_counts()

print("Distribution of students' experience with Python programming (in months):")
print(experience_distribution)
# Out:
# Distribution of students' experience with Python programming (in months):
# Experience with python (Months)
# 5    1239
# 3    1006
# 8     800
# 6     738
# 7     633
# 4     463
# Name: count, dtype: int64

# %% [markdown]
# **Question 5:** What is the average family income of the student?
#
# **Answer:** Average family income of the students: 129288.78868620619

# %%
# Calculate the average family income of the students
average_family_income = df['Family Income'].mean()

print(f"Average family income of the students: {average_family_income}")
# Out:
# Average family income of the students: 129288.78868620619

# %% [markdown]
# **Question 6:** How does the GPA vary among different colleges? (Show top 5 results only)
#
# **Answer:**
#
# **Top 5 colleges with the highest average GPA (CGPA):
# College Name**
#
# 1) THAKUR INSTITUTE OF MANAGEMENT STUDIES, CAREER DEVELOPMENT & RESEARCH - [TIMSCDR] -   8.585714
#
# 2) St Xavier's College  -                                                                8.578571
#
# 3) B. K. Birla College of Arts, Science & Commerce (Autonomous), Kalyan           -      8.456410
#
# 4) Symbiosis Institute of Technology, Pune                                     -         8.303448
#
# 5) AP SHAH INSTITUTE OF TECHNOLOGY    -                                                  8.283333

# %%
# Group by 'College Name' and calculate the average CGPA for each college
college_gpa_distribution = df.groupby('College Name')['CGPA'].mean()

# Sort the colleges by average CGPA in descending order
sorted_college_gpa = college_gpa_distribution.sort_values(ascending=False)

# Get the top 5 colleges with the highest average CGPA
top_5_colleges = sorted_college_gpa.head(5)

print("Top 5 colleges with the highest average GPA (CGPA):")
print(top_5_colleges)
# Out:
# Top 5 colleges with the highest average GPA (CGPA):
# College Name
# THAKUR INSTITUTE OF MANAGEMENT STUDIES, CAREER DEVELOPMENT & RESEARCH - [TIMSCDR]    8.585714
# St Xavier's College                                                                  8.578571
# B. K. Birla College of Arts, Science & Commerce (Autonomous), Kalyan                 8.456410
# Symbiosis Institute of Technology, Pune                                              8.303448
# AP SHAH INSTITUTE OF TECHNOLOGY                                                      8.283333
# Name: CGPA, dtype: float64

# %% [markdown]
# **QUESTION 7:** Are there any outliers in the quantity (number of courses completed) attribute?
#
# **Answer:** There are no outliers in the quantity attribute.

# %%
import numpy as np

# Calculate the first quartile (Q1) and third quartile (Q3)
Q1 = df['Quantity'].quantile(0.25)
Q3 = df['Quantity'].quantile(0.75)

# Calculate the Interquartile Range (IQR)
IQR = Q3 - Q1

# Define the lower and upper bounds for outliers
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Identify outliers in the 'Quantity' column
outliers = df[(df['Quantity'] < lower_bound) | (df['Quantity'] > upper_bound)]

print("Number of outliers in the 'Quantity' column:", outliers.shape[0])
print("Outliers in the 'Quantity' column:")
print(outliers)
# Out:
# Number of outliers in the 'Quantity' column: 0
# Outliers in the 'Quantity' column:
# Empty DataFrame
# Columns: [First Name, Email ID, Quantity, Events, Attendee Status, College Name, How did you come to know about this event?, Specify in "Others" (how did you come to know about this event), Designation, Year of Graduation, City, CGPA, Experience with python (Months), Family Income, Expected salary (Lac), Leadership- skills]
# Index: []

# %% [markdown]
# **Question 8:** What is the Average GPA for student from each city?
#
# **Answer:** Average GPA (CGPA) for students from each city:
#
# City:
#
# Kolhapur   -  8.557143
#
# Raipur      - 8.507143
#
# Sonipat      -8.464286
#
# Gurugram  -   8.459259
#
# Puri   -      8.450000
#
# -------
#
# Panipat   -   7.615385
#
# Nashik   -    7.592857
#
# Daman     -   7.421429
#
# Rewari    -   7.392308
#
# New Delhi   - 7.307143

# %%
# Group by 'City' and calculate the average CGPA for each city
city_gpa_average = df.groupby('City')['CGPA'].mean()

# Sort the results if needed, for example, by average GPA in descending order
sorted_city_gpa_average = city_gpa_average.sort_values(ascending=False)

print("Average GPA (CGPA) for students from each city:")
print(sorted_city_gpa_average)
# Out:
# Average GPA (CGPA) for students from each city:
# City
# Kolhapur     8.557143
# Raipur       8.507143
# Sonipat      8.464286
# Gurugram     8.459259
# Puri         8.450000
#                ...
# Panipat      7.615385
# Nashik       7.592857
# Daman        7.421429
# Rewari       7.392308
# New Delhi    7.307143
# Name: CGPA, Length: 177, dtype: float64

# %% [markdown]
# **Question 9:** Can we identify any relationship between family income and GPA?
#
# **Answer:** A correlation coefficient of 0.02 suggests a very weak positive correlation between Family Income and CGPA.

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
plt.scatter(df['Family Income'], df['CGPA'], alpha=0.5)
plt.title('Relationship between Family Income and CGPA')
plt.xlabel('Family Income')
plt.ylabel('CGPA')
plt.grid(True)
plt.show()

# %%
correlation = df[['Family Income', 'CGPA']].corr().iloc[0, 1]
print(f"Correlation coefficient between Family Income and CGPA: {correlation:.2f}")
# Out:
# Correlation coefficient between Family Income and CGPA: 0.02

# %% [markdown]
# # MODERATE QUESTION
# **QUESTION 10:** How many students from various cities? (Solve using data visualisation tool).
#
# **Answer:**
# ![download.png](data:image/png;base64,...)

# %%
# Prepare the data for plotting
students_per_city = df['City'].value_counts()

# Create the bar plot
plt.figure(figsize=(50, 8))
barplot = sns.barplot(x=students_per_city.index, y=students_per_city.values, palette='viridis')

# Add titles and labels
plt.title('Number of Students from Various Cities')
plt.xlabel('City')
plt.ylabel('Number of Students')

# Rotate x-axis labels for better readability
plt.xticks(rotation=90)

# Annotate each bar with the count value
for i in range(len(students_per_city)):
    barplot.text(i, students_per_city.values[i] + 1, str(students_per_city.values[i]), ha='center', va='bottom')

# Display the plot
plt.show()
# Out:
# <ipython-input-40-abf40dc5ad7a>:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   barplot = sns.barplot(x=students_per_city.index, y=students_per_city.values, palette='viridis')
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# ...

# %% [markdown]
# **QUESTION 11:** How does the expected salary vary based on factors like 'GPA', 'Family income', 'Experience with python (Months)'?
#
#
# **ANSWER:** None of the three factors (GPA, family income, experience with Python) show a strong correlation with expected salary.
#
# This implies that other unmeasured factors (such as specific skills, internships, job market trends, personal aspirations, etc.) may play a more significant role in determining a student's expected salary.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Scatter plots for each factor against expected salary

plt.figure(figsize=(16, 5))

# Plot 1: Expected Salary vs GPA
plt.subplot(1, 3, 1)
sns.scatterplot(x='CGPA', y='Expected salary (Lac)', data=df)
plt.title('Expected Salary vs GPA')
plt.xlabel('GPA')
plt.ylabel('Expected Salary (Lac)')

# Plot 2: Expected Salary vs Family Income
plt.subplot(1, 3, 2)
sns.scatterplot(x='Family Income', y='Expected salary (Lac)', data=df)
plt.title('Expected Salary vs Family Income')
plt.xlabel('Family Income')
plt.ylabel('Expected Salary (Lac)')

# Plot 3: Expected Salary vs Experience with Python (Months)
plt.subplot(1, 3, 3)
sns.scatterplot(x='Experience with python (Months)', y='Expected salary (Lac)', data=df)
plt.title('Expected Salary vs Experience with Python')
plt.xlabel('Experience with Python (Months)')
plt.ylabel('Expected Salary (Lac)')

plt.tight_layout()
plt.show()

# Pair Plot to see all possible relationships
sns.pairplot(df[['CGPA', 'Family Income', 'Experience with python (Months)', 'Expected salary (Lac)']])
plt.show()

# Calculate correlation coefficients
correlation = df[['CGPA', 'Family Income', 'Experience with python (Months)', 'Expected salary (Lac)']].corr()
print("Correlation coefficients:")
print(correlation)
# Out:
# Correlation coefficients:
#                                      CGPA  Family Income  \
# CGPA                             1.000000       0.016729
# Family Income                    0.016729       1.000000
# Experience with python (Months) -0.014132       0.054351
# Expected salary (Lac)            0.181815       0.034816
#
#                                  Experience with python (Months)  \
# CGPA                                                   -0.014132
# Family Income                                           0.054351
# Experience with python (Months)                         1.000000
# Expected salary (Lac)                                   0.115855
#
#                                  Expected salary (Lac)
# CGPA                                          0.181815
# Family Income                                 0.034816
# Experience with python (Months)               0.115855
# Expected salary (Lac)                         1.000000

# %% [markdown]
# **QUESTION 12:** Which event tend to attract more students from specific fields of study?
#
# **ANSWER:** The events that tend to attract the most students are:
#
# Art of Resume Building with 470 students.
#
# Data Visualization using Power BI with 450 students.

# %%
# Group by 'Events' and 'Designation'
event_field_distribution = df.groupby(['Events', 'Designation']).size().reset_index(name='Count')

# Print the results
print(event_field_distribution)
# Out:
#                                          Events      Designation  Count
# 0                        Art of Resume Building         Students    470
# 1                       Artificial Intelligence         Students    125
# 2             Data Visualization using Power BI         Students    450
# 3                               Hello ML and DL         Students    261
# 4                                     IAC - Q&A  Asst. Professor     23
# ..                                          ...              ...    ...
# 79          Skill and Employability Enhancement         Students    318
# 80  Talk on Skill and Employability Enhancement         Students    379
# 81                    The Agile Ways of Working         Students    121
# 82             The SDLC & their transformations         Students    142
# 83     Transformation with DevOps: The Easy Way         Students     92
#
# [84 rows x 3 columns]

# %% [markdown]
# **Question 14:** How many students are graduating by the end of 2024?
#
# **Answer:** 1506

# %%
# Filter the DataFrame for students graduating by the end of 2024
students_graduating_2024 = df[df['Year of Graduation'] == 2024]

# Count the number of such students
number_of_students_graduating_2024 = students_graduating_2024.shape[0]

print(number_of_students_graduating_2024)
# Out:
# 1506

# %% [markdown]
# **Question 15:** Which promotion channel brings in more student participations for the event?
#
# **Answer:** Whatsapp brought most number of students i.e 3418

# %%
# Group by the promotion channel and count the number of participants
promotion_channel_distribution = df['How did you come to know about this event?'].value_counts().reset_index()
promotion_channel_distribution.columns = ['Promotion Channel', 'Number of Participants']

# Print the results
print(promotion_channel_distribution)
# Out:
#            Promotion Channel  Number of Participants
# 0                   Whatsapp                    3418
# 1                      Email                     477
# 2    SPOC/ College Professor                     325
# 3                     Others                     154
# 4   Cloud Counselage Website                     143
# 5                    Youtube                     124
# 6                   LinkedIn                      78
# 7                   Facebook                      55
# 8                  Instagram                      48
# 9          Friend/ Classmate                      39
# 10                  Telegram                      16
# 11                   Twitter                       2

# %% [markdown]
# **Question 16:** Find the total number of students who attended the events related to Data Science? (From all Data Science related courses.)
#
# **Answer:** 1256

# %%
# Define the Data Science-related events
data_science_events = [
    'Data Visualization using Power BI',
    'Artificial Intelligence',
    'Hello ML and DL',
    'IS DATA SCIENCE FOR YOU?',
    'RPA: A Boon or A Bane'
]

# Filter the DataFrame for Data Science-related events
data_science_attendees = df[df['Events'].isin(data_science_events)]

# Calculate the total number of students who attended Data Science-related events
total_data_science_attendees = data_science_attendees['Quantity'].sum()

print(total_data_science_attendees)
# Out:
# 1256

# %% [markdown]
# **Question 17:** Those who have high CGPA & More experience in language those who had high expectations for salary? (Avg)
#
# **Answer:** YES . Average Expected Salary: 1694288.5771543086

# %%
# Define criteria for high CGPA and more experience
high_cgpa_threshold = 8.0
high_experience_threshold = 5

# Filter the DataFrame based on these criteria
filtered_df = df[(df['CGPA'] > high_cgpa_threshold) & (df['Experience with python (Months)'] > high_experience_threshold)]

# Calculate the average expected salary for the filtered data
average_expected_salary = filtered_df['Expected salary (Lac)'].mean()

print(f"Average Expected Salary: {average_expected_salary}")
# Out:
# Average Expected Salary: 1694288.5771543086

# %% [markdown]
# **Question 18:** How many students know about the event from their colleges? Which of these Top 5 colleges?
#
# **Answer:** Total number of students who knew about the event from their colleges: 69
#
# Top 5 colleges with the most students knowing about the event from their college:
#
# Sr. no.    -   College Name     -   Number of Students
#
# 1)                                   Wilson college   -                 5
#
# 2)       vidyalankar institute of technology, mumbai   -                5
#
# 3)                                   wilson college     -               4
#
# 4)                GOVERNMENT POLYTECHNIC GANDHINAGAR     -              4
#
# 5) g h raisoni institut of engineering and techno...      -             3

# %%
# Filter data for students who knew about the event from their colleges
students_from_colleges = df[df['Specify in "Others" (how did you come to know about this event)'] == 'College']

# Count the number of students from each college
college_counts = students_from_colleges['College Name'].value_counts().reset_index()
college_counts.columns = ['College Name', 'Number of Students']

# Get the top 5 colleges
top_5_colleges = college_counts.head(5)

# Print the number of students and the top 5 colleges
total_students_from_colleges = students_from_colleges.shape[0]
print("ANSWER:")
print(f"Total number of students who knew about the event from their colleges: {total_students_from_colleges}")
print("Top 5 colleges with the most students knowing about the event from their college:")
print(top_5_colleges)
# Out:
# ANSWER:
# Total number of students who knew about the event from their colleges: 69
# Top 5 colleges with the most students knowing about the event from their college:
#                                         College Name  Number of Students
# 0                                    Wilson college                    5
# 1        vidyalankar institute of technology, mumbai                   5
# 2                                    wilson college                    4
# 3                 GOVERNMENT POLYTECHNIC GANDHINAGAR                   4
# 4  g h raisoni institut of engineering and techno...                   3

# %% [markdown]
# # CONCLUSION
#
# In this project, we looked at data from student interns to understand how their academic performance, participation in events, and career goals impact their success in getting internships. Our analysis showed that students with better grades and those involved in more activities tended to have better chances of getting selected.
#
# This highlights the importance of balancing good academic performance with active participation in extracurriculars when applying for internships or jobs. Further studies could explore other skills or experiences that help students stand out even more in the competitive job market.
